# %%
import pickle

with open('/lfs/ampere8/0/kaif/model_evals/Algebra_test/Deepseek-7b-Instruct/teacher_forcing/output.pkl', 'rb') as f:
    t = pickle.load(f)

# %%
len(t)
# Out:
# 6

# %%
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0,1,2,3"

from pathlib import Path
import json
from utils import load_arguments, get_boxed_answer
from latex_formater import get_final_answer, process_docs, process_results, is_equiv
# from model_generate import load_datasets, prompt_generator, load_model
# from blocks import Batch, Block
import itertools
import pandas as pd

root_dir = Path('~/GitHub/FileTransfer/model_evals').expanduser()

# load the name maps
with open('name_maps.json', 'r') as f:
    name_maps = json.load(f)
    DATASET_MAP = name_maps['DATASET_MAP']
    MODEL_MAP = name_maps['MODEL_MAP']

# %%
def load_predictions(path):
    print(path)
    if not (path / 'output.json').exists():
        return []
    with open(path / 'output.json', 'r') as f:
        return json.load(f)


predictions = pd.DataFrame([
    {
        'dataset': dataset.name,
        'model': model.name,
        'method': method.name,
        'prediction': prediction,
        'i': i,
        'generation_args': load_arguments(method / 'args.json')
    }
    for dataset in root_dir.iterdir()
    for model in dataset.iterdir()
    for method in model.iterdir()
    for i, prediction in enumerate(load_predictions(method))
])
args = predictions.iloc[0]['generation_args']
# Out:
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Qwen-14b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Meta-Llama-3-70b-Instruct/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Meta-Llama-3-70b-Instruct/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Mixtral-8x7b-Instruct-v0.1/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Mixtral-8x7b-Instruct-v0.1/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Llama-2-7b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Llama-2-7b/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Gemma-1.1-7b-Instruct/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Gemma-1.1-7b-Instruct/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Deepseek-7b-Instruct/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Deepseek-7b-Instruct/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Mixtral-8x22b-Instruct-v0.1/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Llama-2-13b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Llama-2-13b/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Deepseek-7b-RL/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Deepseek-7b-RL/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Abel-7b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Abel-7b/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Llama-2-70b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Llama-2-70b/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Mistral-7b-Instruct-v0.2/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Mistral-7b-Instruct-v0.2/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Qwen-72b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Gemma-7b-Instruct/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Gemma-7b-Instruct/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Meta-Llama-3-8b-Instruct/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Meta-Llama-3-8b-Instruct/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/LLeMMA-7b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/LLeMMA-7b/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Qwen-7b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/LLeMMA-34b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/LLeMMA-34b/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Deepseek-67b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Deepseek-67b/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Counting_and_Probability_train/Mixtral-8x22b-v0.1/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Qwen-14b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Meta-Llama-3-70b-Instruct/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Meta-Llama-3-70b-Instruct/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Mixtral-8x7b-Instruct-v0.1/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Mixtral-8x7b-Instruct-v0.1/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Llama-2-7b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Llama-2-7b/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Gemma-1.1-7b-Instruct/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Gemma-1.1-7b-Instruct/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Deepseek-7b-Instruct/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Deepseek-7b-Instruct/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Mixtral-8x22b-Instruct-v0.1/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Llama-2-13b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Llama-2-13b/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Deepseek-7b-RL/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Deepseek-7b-RL/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Abel-7b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Abel-7b/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Llama-2-70b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Llama-2-70b/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Mistral-7b-Instruct-v0.2/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Mistral-7b-Instruct-v0.2/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Qwen-72b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Gemma-7b-Instruct/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Gemma-7b-Instruct/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Meta-Llama-3-8b-Instruct/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Meta-Llama-3-8b-Instruct/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/LLeMMA-7b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/LLeMMA-7b/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Qwen-7b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/LLeMMA-34b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/LLeMMA-34b/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Deepseek-67b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Deepseek-67b/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Geometry_train/Mixtral-8x22b-v0.1/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Intermediate_Algebra_train/Qwen-14b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Intermediate_Algebra_train/Meta-Llama-3-70b-Instruct/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Intermediate_Algebra_train/Meta-Llama-3-70b-Instruct/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Intermediate_Algebra_train/Mixtral-8x7b-Instruct-v0.1/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Intermediate_Algebra_train/Mixtral-8x7b-Instruct-v0.1/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Intermediate_Algebra_train/Llama-2-7b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Intermediate_Algebra_train/Llama-2-7b/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Intermediate_Algebra_train/
teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Algebra_train/LLeMMA-7b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Algebra_train/LLeMMA-7b/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Algebra_train/Qwen-7b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Algebra_train/LLeMMA-34b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Algebra_train/LLeMMA-34b/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Algebra_train/Deepseek-67b/autoregressive
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Algebra_train/Deepseek-67b/teacher_forcing
# /lfs/ampere1/0/kaif/GitHub/FileTransfer/model_evals/Algebra_train/Mixtral-8x22b-v0.1/teacher_forcing

# %%
predictions.groupby(['dataset', 'model', 'method']).size()
# Out:
# dataset            model                       method
# Algebra_test       Abel-7b                     autoregressive     1187
#                                                teacher_forcing    1187
#                    Deepseek-67b                autoregressive     1187
#                                                teacher_forcing    1187
#                    Deepseek-7b-Instruct        autoregressive     1187
#                                                                   ...
# Precalculus_train  Mixtral-8x7b-Instruct-v0.1  autoregressive      746
#                                                teacher_forcing     746
#                    Qwen-14b                    autoregressive      746
#                    Qwen-72b                    autoregressive      746
#                    Qwen-7b                     autoregressive      746
# Length: 490, dtype: int64

# %%
# %%capture
DATASET_CONFIGS = {
    'EleutherAI/hendrycks_math': {
        'subsets': ['algebra', 'counting_and_probability', 'geometry', 'intermediate_algebra',
                    'number_theory', 'prealgebra', 'precalculus'],
        'aliases': ['hendrycks_math', 'math', 'hendrycks'],
    }
}

DATASET_ALIASES = {alias: dataset_name
                   for dataset_name, config in DATASET_CONFIGS.items()
                   for alias in config['aliases']}
DATASET_ALIASES.update({dataset_name: dataset_name for dataset_name in DATASET_CONFIGS})
import datasets as hf_datasets


def load_datasets(args):
    datasets = {}
    for dataset_name in args.dataset.split(','):
        dataset_name = dataset_name.strip()
        assert dataset_name in DATASET_ALIASES, f'Unknown dataset {dataset_name}'
        dataset_name = DATASET_ALIASES[dataset_name]

        for subset in DATASET_CONFIGS[dataset_name]['subsets']:
            try:
                dataset = hf_datasets.load_dataset(dataset_name, subset)[args.split]
            except ValueError as e:  # @TODO: get right exception type
                print(e)
                print(f'Error while loading {dataset_name}:{subset}. Redownloading...')
                dataset = hf_datasets.load_dataset(dataset_name, subset, download_mode='force_redownload',
                                                   verification_mode='no_checks')[args.split]
            datasets[f'{dataset_name}:{subset}'] = dataset

    return datasets

train_args = args
train_args.split = 'train'
test_args = args
test_args.split = 'test'
datasets = {
    'train': load_datasets(train_args),
    'test': load_datasets(test_args)
}
datasets = pd.DataFrame([
    {
        'dataset': f'{DATASET_MAP[dataset_name]}_{split}',
        'i': i,
        **datapoint
    }
    
    for split in ['train', 'test']
    for dataset_name, dataset in datasets[split].items()
    for i, datapoint in enumerate(process_docs(dataset))
])


# def groupby(datasets, key):
#     return {k: list(g) for k, g in itertools.groupby(datasets, key=lambda x: x[key])}

# %%
# merge predictions and datasets on ['dataset', 'i']
results = datasets.merge(predictions, on=['dataset', 'i'])

save_path = Path('~/GitHub/gold-ai-olympiad/data/MATH/Predictions/').expanduser()
save_path.mkdir(exist_ok=True, parents=True)
import json

results_copy = results.copy()
results_copy['generation_args'] = results_copy['generation_args'].apply(lambda x: x.__dict__)

# save each dataset in a different file
for dataset_name, dataset in results_copy.groupby('dataset'):
    with open(save_path / f'{dataset_name}.json', 'w') as f:
        json.dump(dataset.to_dict('records'), f)

# %%
# load the results and combine them back into a single dataframe
save_path = Path('~/GitHub/gold-ai-olympiad/data/MATH/Predictions/').expanduser()
results = pd.concat([
    pd.read_json(save_path / f)
    for f in save_path.iterdir()
    if f.suffix == '.json' and f.stem in ['Algebra_test']
])

# %%
results.dataset.unique()
# Out:
# array(['Algebra_test'], dtype=object)

# %%
class Metric():
    def __init__(self):
        super().__init__()

    def process(self, results):
        pass

    def __call__(self, results):
        return self.process(results)


def apply_metric(predictions, metric, datasets):
    m = metric(datasets)
    results = m(predictions)
    return results


from latex_formater import get_final_answer


class BoxedMatch(Metric):
    def process(self, results):
        results['boxed_pred'] = results['prediction'].apply(get_final_answer)
        results['boxed_true'] = results['boxed']
        results['boxed_match'] = results['boxed_true'] == results['boxed_pred']

        # very slow, probably don't use
        # results['match'] = results.apply(lambda x: is_equiv(x['boxed_true'], x['boxed_pred']), axis=1)

        # set first columns to be ['dataset', 'i', 'model', 'method', 'boxed_true', 'boxed_pred', 'match', ...]
        # cols = ['dataset', 'i', 'model', 'method', 'boxed_true', 'boxed_pred', 'boxed_match']
        # cols.extend([col for col in results.columns if col not in cols])
        return results  #[cols]

# %%
results['method'].unique()
# Out:
# array(['autoregressive'], dtype=object)

# %%
boxed_match = BoxedMatch()
ar_df = results.query('method == "autoregressive"')
results = boxed_match(ar_df)

save_path = Path('~/GitHub/gold-ai-olympiad/data/MATH/Predictions/BoxedMatch').expanduser()
import pickle
with open(save_path / 'results.pkl', 'wb') as f:
    pickle.dump(results, f)
# Out:
# /tmp/user/21882/ipykernel_3303524/2018833170.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results['boxed_pred'] = results['prediction'].apply(get_final_answer)
# /tmp/user/21882/ipykernel_3303524/2018833170.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results['boxed_true'] = results['boxed']
# /tmp/user/21882/ipykernel_3303524/2018833170.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results['boxed_match'] = results['boxed_true'] == results['boxed_pred']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 7
#       5 save_path = Path('~/GitHub/gold-ai-olympiad/data/MATH/Predictions/BoxedMatch').expanduser()
#       6 import pickle
# ----> 7 with open(save_path / 'results.pkl', 'wb') as f:
#       8     pickle.dump(results, f)
#
# File ~/miniforge/envs/TheoremSense/lib/python3.10/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/lfs/ampere1/0/kaif/GitHub/gold-ai-olympiad/data/MATH/Predictions/BoxedMatch/results.pkl'

# %%
tf_df = results.query('method == "teacher_forcing"')
tf_df.dataset.unique()
# Out:
# array(['Intermediate_Algebra_train', 'Precalculus_train',
#        'Counting_and_Probability_train', 'Prealgebra_train',
#        'Number_Theory_train', 'Algebra_train', 'Geometry_train'],
#       dtype=object)
